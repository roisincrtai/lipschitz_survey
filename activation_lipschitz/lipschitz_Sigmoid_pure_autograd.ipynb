# %% [markdown]
# # Lipschitz of Sigmoid (full autograd)

# %%
import torch
import torch.nn.functional as F
from torch.autograd.functional import jacobian as autograd_jacobian
import math


seed = 1
torch.manual_seed(seed)
ns = list(range(2, 16))      
steps = 10000                
lr = 1e-1                    
    
def Sigmoid(x): 
    return torch.sigmoid(x)


for n in ns:
    g = torch.Generator().manual_seed(seed)
    
    x = (0.01 * torch.randn(n, generator=g, dtype=torch.float64)).requires_grad_(True)
    
    optimizer = torch.optim.Adam([x], lr=lr)

    for _ in range(steps):
            
        J = autograd_jacobian(Sigmoid, x, create_graph=True)
                
        #K = torch.sqrt(torch.sum(J*J))   #<- it's ok but may have numeric error
        K = torch.linalg.norm(J, ord=2)   #<- more accurate              

        optimizer.zero_grad()
        (-K).backward()                                 
        optimizer.step()

    print(f"Sigmoid n = {n:2d}  Estimated Lipschitz constant = {K.item():.6f} at x = {x.detach().numpy()}")
# Out:
# Sigmoid n =  2  Estimated Lipschitz constant = 0.250000 at x = [-1.15983444e-10 -5.97833453e-01]
# Sigmoid n =  3  Estimated Lipschitz constant = 0.250000 at x = [ 3.46816281e-10 -5.53170091e-01 -5.99725943e-01]
# Sigmoid n =  4  Estimated Lipschitz constant = 0.250000 at x = [ 1.57871780e-16 -5.53170091e-01 -5.99725943e-01 -5.28469913e-01]
# Sigmoid n =  5  Estimated Lipschitz constant = 0.250000 at x = [ 5.70847453e-08 -5.53170091e-01 -5.99725943e-01 -5.16639828e-01
#   5.30155642e-01]
# Sigmoid n =  6  Estimated Lipschitz constant = 0.250000 at x = [-1.52240040e-05 -5.31984149e-01 -5.99725943e-01 -5.09908207e-01
#   5.18325226e-01  5.54147663e-01]
# Sigmoid n =  7  Estimated Lipschitz constant = 0.250000 at x = [-5.05991540e-01 -5.31984149e-01 -5.99725943e-01 -5.09908207e-01
#   5.18325226e-01  5.54147663e-01  7.59618788e-06]
# Sigmoid n =  8  Estimated Lipschitz constant = 0.250000 at x = [-5.04680457e-01 -5.31984149e-01 -5.99725943e-01 -5.06390372e-01
#   5.11593269e-01  5.54147663e-01  1.74333611e-05 -5.19021566e-01]
# Sigmoid n =  9  Estimated Lipschitz constant = 0.250000 at x = [-5.04680457e-01 -5.31984149e-01 -5.99725943e-01 -5.06390372e-01
#   5.11593269e-01  5.54147663e-01 -5.11614553e-08 -5.19021566e-01
#   5.01319031e-01]
# Sigmoid n = 10  Estimated Lipschitz constant = 0.250000 at x = [-5.04972575e-01 -5.31984149e-01 -5.99725943e-01 -5.05079232e-01
#   5.11593269e-01  5.54147663e-01  4.92142789e-10 -5.19021566e-01
#   5.02823606e-01  5.06970424e-01]
# Sigmoid n = 11  Estimated Lipschitz constant = 0.249998 at x = [-0.50497257 -0.53198415 -0.59972594 -0.50507923  0.51159327  0.55414766
#  -0.00857195 -0.51902157  0.50527197  0.50697042  0.50417423]
# Sigmoid n = 12  Estimated Lipschitz constant = 0.250000 at x = [-5.06476827e-01 -5.20152895e-01 -5.55056051e-01 -5.05371292e-01
#   5.08075091e-01  5.32960504e-01 -1.65369262e-05 -5.12289382e-01
#   5.08471695e-01  5.05659188e-01  5.06622501e-01  5.99747978e-01]
# Sigmoid n = 13  Estimated Lipschitz constant = 0.250000 at x = [-5.08924863e-01 -5.13420083e-01 -5.55056051e-01 -5.06875486e-01
#   5.06763602e-01  5.32960504e-01 -1.42544043e-05 -5.08770973e-01
#   5.12279884e-01  5.05951150e-01  5.09822136e-01  5.99747978e-01
#   5.20847277e-01]
# Sigmoid n = 14  Estimated Lipschitz constant = 0.250000 at x = [-5.08924863e-01 -5.13420083e-01 -5.55056051e-01 -5.06875486e-01
#   5.06763602e-01  5.32960504e-01 -8.55424270e-08 -5.08770973e-01
#   5.16587340e-01  5.05951150e-01  5.09822136e-01  5.99747978e-01
#   5.20847277e-01  5.12898412e-01]
# Sigmoid n = 15  Estimated Lipschitz constant = 0.250000 at x = [-5.12124256e-01 -5.13420083e-01 -5.55056051e-01 -5.09323463e-01
#   5.07055307e-01  5.32960504e-01  2.79264998e-09 -5.08770973e-01
#   5.21308615e-01  5.07455244e-01  5.13630233e-01  5.99747978e-01
#   5.20847277e-01  5.17205828e-01 -5.07056014e-01]
